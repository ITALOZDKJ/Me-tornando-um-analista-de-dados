# %% [markdown]
# <a href="https://colab.research.google.com/github/ITALOZDKJ/Me-tornando-um-analista-de-dados/blob/main/features_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de bibliotecas

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose as sd
import pandas_datareader.data as web
import numpy as np

# %% [markdown]
# # Coleta de dados das negociações de ativos

# %%
tricker = yf.Ticker('ABEV3.SA')

# %%
ambev = tricker.history(interval='1d', start='2016-01-01', end='2021-10-27')
ambev_m = tricker.history(interval='1mo', start='2016-01-01', end='2021-10-27')

# %%
ambev
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2016-01-04  15.222131  15.222131  14.775683  14.775683  13206900        0.0
# 2016-01-05  14.810026  15.041836  14.689830  15.007493  10774200        0.0
# 2016-01-06  14.904467  15.007493  14.767099  14.861539   7739100        0.0
# 2016-01-07  14.741346  14.870128  14.466609  14.466609  15316400        0.0
# 2016-01-08  14.535293  14.767103  14.535293  14.655490  10684000        0.0
# ...               ...        ...        ...        ...       ...        ...
# 2021-10-20  15.300000  15.580000  15.210000  15.410000  19273600        0.0
# 2021-10-21  15.000000  15.280000  14.850000  15.140000  23499300        0.0
# 2021-10-22  14.830000  15.230000  14.540000  15.000000  29599100        0.0
# 2021-10-25  15.010000  15.440000  15.000000  15.270000  19933100        0.0
# 2021-10-26  15.150000  15.320000  15.050000  15.160000  20648000        0.0
#
#             Stock Splits
# Date
# 2016-01-04             0
# 2016-01-05             0
# 2016-01-06             0
# 2016-01-07             0
# 2016-01-08             0
# ...                  ...
# 2021-10-20             0
# 2021-10-21             0
# 2021-10-22             0
# 2021-10-25             0
# 2021-10-26             0
#
# [1444 rows x 7 columns]

# %% [markdown]
# # Extração de novos dados

# %%
# Extraindo dados e reiniciando index
ambev = tricker.history(interval='1d', start='2017-01-01', end='2021-10-27')
desempenho_ambev = ambev.copy()
desempenho_ambev.reset_index(inplace=True)

# %%
def features_initial(x):
    x['Day'] = x['Date'].dt.day
    x['Month'] = x['Date'].dt.month
    x['Year'] = x['Date'].dt.year
    x['Rentability%'] = round((x['Close']/x['Close'].shift()) * 100 -100, 2)
    x['Rentability pure'] = round(x['Close'] - x['Close'].shift(),2)

# %%
desempenho_ambev
# Out:
#            Date       Open       High        Low      Close    Volume  \
# 0    2017-01-02  14.540122  14.824873  14.468934  14.513426   4265400
# 1    2017-01-03  14.682498  14.833773  14.629108  14.807076   9535500
# 2    2017-01-04  14.824875  14.824875  14.620210  14.691398   9426500
# 3    2017-01-05  14.700298  14.904963  14.664704  14.771486  11555800
# 4    2017-01-06  14.762585  14.807077  14.557921  14.646904   7863200
# ...         ...        ...        ...        ...        ...       ...
# 1190 2021-10-20  15.300000  15.580000  15.210000  15.410000  19273600
# 1191 2021-10-21  15.000000  15.280000  14.850000  15.140000  23499300
# 1192 2021-10-22  14.830000  15.230000  14.540000  15.000000  29599100
# 1193 2021-10-25  15.010000  15.440000  15.000000  15.270000  19933100
# 1194 2021-10-26  15.150000  15.320000  15.050000  15.160000  20648000
#
#       Dividends  Stock Splits
# 0           0.0             0
# 1           0.0             0
# 2           0.0             0
# 3           0.0             0
# 4           0.0             0
# ...         ...           ...
# 1190        0.0             0
# 1191        0.0             0
# 1192        0.0             0
# 1193        0.0             0
# 1194        0.0             0
#
# [1195 rows x 8 columns]

# %%
features_initial(desempenho_ambev)

# %%
desempenho_ambev
# Out:
#            Date       Open       High        Low      Close    Volume  \
# 0    2017-01-02  14.540122  14.824873  14.468934  14.513426   4265400
# 1    2017-01-03  14.682498  14.833773  14.629108  14.807076   9535500
# 2    2017-01-04  14.824875  14.824875  14.620210  14.691398   9426500
# 3    2017-01-05  14.700298  14.904963  14.664704  14.771486  11555800
# 4    2017-01-06  14.762585  14.807077  14.557921  14.646904   7863200
# ...         ...        ...        ...        ...        ...       ...
# 1190 2021-10-20  15.300000  15.580000  15.210000  15.410000  19273600
# 1191 2021-10-21  15.000000  15.280000  14.850000  15.140000  23499300
# 1192 2021-10-22  14.830000  15.230000  14.540000  15.000000  29599100
# 1193 2021-10-25  15.010000  15.440000  15.000000  15.270000  19933100
# 1194 2021-10-26  15.150000  15.320000  15.050000  15.160000  20648000
#
#       Dividends  Stock Splits  Action_value  Day  Month  Year  Rentability%  \
# 0           0.0             0           NaN    2      1  2017           NaN
# 1           0.0             0           NaN    3      1  2017          2.02
# 2           0.0             0           NaN    4      1  2017         -0.78
# 3           0.0             0           NaN    5      1  2017          0.55
# 4           0.0             0           NaN    6      1  2017         -0.84
# ...         ...           ...           ...  ...    ...   ...           ...
# 1190        0.0             0           NaN   20     10  2021          1.78
# 1191        0.0             0           NaN   21     10  2021         -1.75
# 1192        0.0             0           NaN   22     10  2021         -0.92
# 1193        0.0             0           NaN   25     10  2021          1.80
# 1194        0.0             0           NaN   26     10  2021         -0.72
#
#       Rentability pure
# 0                  NaN
# 1                 0.29
# 2                -0.12
# 3                 0.08
# 4                -0.12
# ...                ...
# 1190              0.27
# 1191             -0.27
# 1192             -0.14
# 1193              0.27
# 1194             -0.11
#
# [1195 rows x 14 columns]

# %% [markdown]
# ## Criando função para extração de mais dados

# %%
# Criando a função
def features_cash(x, y, aporte):
    x.loc[:,'Action_value'] = (y['High'] + y['Low'])/2
    year_temp = 0
    # 
    for year in list(x['Year'].unique()):
        year_temp = x.loc[(x['Year']==year)]
        for month in list(year_temp['Month'].unique()):
            temp = x.loc[(x['Month'] == month) & (x['Year']==year)]
            day = list(temp[0:]['Day'])
            day = day[0]
            x.loc[(x['Day'] == day) & (x['Month'] == month) & (x['Year'] == year),['Bougth']] = aporte
    # Valor de aporte
    x.loc[:,'Valor_aportado'] = x['Bougth'] * x['Action_value']
    x.fillna(0, inplace=True)
    # A soma das ações
    x['Total_actions'] = 0
    for pos,c in enumerate(x['Bougth']):
        x.loc[pos,'Total_actions'] = x.loc[:pos,'Bougth'].sum()
    
    # A soma do valor investido 
    x['Total_aport'] = 0
    for pos,c in enumerate(x['Total_actions']):
        x.loc[pos,'Total_aport'] = x.loc[:pos,'Total_actions'].sum()
        
    # The sum of dividends receives with actual aports
    x['Dividend_receive'] = x['Total_actions'] * x['Dividends']
    
    # The final dividends receives
    x['Total_receive'] = 0
    for pos,c in enumerate(x['Dividend_receive']):
        x.loc[pos,'Total_receive'] = x.loc[:pos,'Dividend_receive'].sum()

# %%
features_cash(desempenho_ambev, ambev, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_91026/3950871997.py in <module>
# ----> 1 features_cash(desempenho_ambev, ambev, 10)
#
# /tmp/ipykernel_91026/1048145759.py in features_cash(x, y, aporte)
#       4     year_temp = 0
#       5     #
# ----> 6     for year in list(x['Year'].unique()):
#       7         year_temp = x.loc[(x['Year']==year)]
#       8         for month in list(year_temp['Month'].unique()):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Year'

# %%
desempenho_ambev
# Out:
#            Date       Open       High        Low      Close    Volume  \
# 0    2017-01-02  14.540124  14.824875  14.468936  14.513428   4265400
# 1    2017-01-03  14.682499  14.833773  14.629109  14.807077   9535500
# 2    2017-01-04  14.824874  14.824874  14.620209  14.691397   9426500
# 3    2017-01-05  14.700296  14.904960  14.664701  14.771483  11555800
# 4    2017-01-06  14.762585  14.807077  14.557921  14.646904   7863200
# ...         ...        ...        ...        ...        ...       ...
# 1190 2021-10-20  15.300000  15.580000  15.210000  15.410000  19273600
# 1191 2021-10-21  15.000000  15.280000  14.850000  15.140000  23499300
# 1192 2021-10-22  14.830000  15.230000  14.540000  15.000000  29599100
# 1193 2021-10-25  15.010000  15.440000  15.000000  15.270000  19933100
# 1194 2021-10-26  15.150000  15.320000  15.050000  15.160000  20648000
#
#       Dividends  Stock Splits  Day  Month  Year  Rentability%  \
# 0           0.0             0    2      1  2017          0.00
# 1           0.0             0    3      1  2017          2.02
# 2           0.0             0    4      1  2017         -0.78
# 3           0.0             0    5      1  2017          0.55
# 4           0.0             0    6      1  2017         -0.84
# ...         ...           ...  ...    ...   ...           ...
# 1190        0.0             0   20     10  2021          1.78
# 1191        0.0             0   21     10  2021         -1.75
# 1192        0.0             0   22     10  2021         -0.92
# 1193        0.0             0   25     10  2021          1.80
# 1194        0.0             0   26     10  2021         -0.72
#
#       Rentability pure  Action_value  Bougth  Valor_aportado  Total_actions  \
# 0                 0.00     14.646906    10.0      146.469055             10
# 1                 0.29     14.731441     0.0        0.000000             10
# 2                -0.12     14.722541     0.0        0.000000             10
# 3                 0.08     14.784831     0.0        0.000000             10
# 4                -0.12     14.682499     0.0        0.000000             10
# ...                ...           ...     ...             ...            ...
# 1190              0.27     15.395000     0.0        0.000000            580
# 1191             -0.27     15.065000     0.0        0.000000            580
# 1192             -0.14     14.885000     0.0        0.000000            580
# 1193              0.27     15.220000     0.0        0.000000            580
# 1194             -0.11     15.185000     0.0        0.000000            580
#
#       Total_aport  Dividend_receive  Total_receive
# 0              10               0.0          0.000
# 1              20               0.0          0.000
# 2              30               0.0          0.000
# 3              40               0.0          0.000
# 4              50               0.0          0.000
# ...           ...               ...            ...
# 1190       348080               0.0        575.675
# 1191       348660               0.0        575.675
# 1192       349240               0.0        575.675
# 1193       349820               0.0        575.675
# 1194       350400               0.0        575.675
#
# [1195 rows x 20 columns]

# %% [markdown]
# ### Espaço para testes e confirmações

# %%
temp = desempenho_ambev.loc[(desempenho_ambev['Month'] == 5) & (desempenho_ambev['Year']==2019)]
a = list(temp[-1:]['Day'])
a[0]

# %%
ambev['Year'].unique()

# %%
desempenho_ambev[desempenho_ambev['Bougth'] != 0]

# %%
year_temp = 0
meses = []
for year in list(desempenho_ambev['Year'].unique()):
        year_temp = desempenho_ambev.loc[(desempenho_ambev['Year']==year)]
        for month in list(year_temp['Month'].unique()):
            meses.append(month)
len(meses)

# %%
desempenho_ambev['Valor_aportado'].sum()

# %%
desempenho_ambev['Rentability pure'].sum() +

# %%
a = pd.Series([1,2,3,4,5,6,7,8])

# %%
a[3:]

# %%
loc[(x['Day'] == 22) & (x['Month']==month),['Bougth']]

# %%
ambev[ambev.index == 1]

# %%
for month in range(1,13):
        x.loc[(x['Day'] == 22) & (x['Month']==month),['Bougth']] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_91026/398708685.py in <module>
#       1 for month in range(1,13):
# ----> 2         x.loc[(x['Day'] == 22) & (x['Month']==month),['Bougth']] = 1
#
# NameError: name 'x' is not defined
